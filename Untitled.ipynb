# %%
from lxml import html
import requests

# %%
page = requests.get('https://www.rottentomatoes.com/top/')
tree = html.fromstring(page.content)

# %%
from urllib.request import urlopen

# %%
url = "https://www.imdb.com/title/tt2582846/reviews"

# %%
page = urlopen(url)
page

# %%
#https://bit.ly/2NyxdAG
from bs4 import BeautifulSoup
import requests
import re

# Download IMDB's Top 250 data
url = 'https://en.wikipedia.org/wiki/The_Fault_in_Our_Stars_(film)'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>The Fault in Our Stars (film) - Wikipedia</title>
# ...

# %%
text = html_soup.find_all('p')
text
# Out:
# [<p class="mw-empty-elt">
#  </p>,
# ...

# %%
def getMovieDetails(url):
    data = {}
    r = requests.get(url=url)
    # Create a BeautifulSoup object
    soup = BeautifulSoup(r.text, 'html.parser')

    #page title
    title = soup.find('title')
    data["title"] = title.string

    # rating
    ratingValue = soup.find("span", {"itemprop" : "ratingValue"})
    data["ratingValue"] = ratingValue.string

    # no of rating given
    ratingCount = soup.find("span", {"itemprop" : "ratingCount"})
    data["ratingCount"] = ratingCount.string

    # name
    titleName = soup.find("div",{'class':'titleBar'}).find("h1")
    data["name"] = titleName.contents[0].replace(u'\xa0', u'')

    # additional details
    subtext = soup.find("div",{'class':'subtext'})
    data["subtext"] = ""
    for i in subtext.contents:
        data["subtext"] += i.string.strip()

    # summary
    summary_text = soup.find("div",{'class':'summary_text'})
    data["summary_text"] = summary_text.string.strip()

    credit_summary_item = soup.find_all("div",{'class':'credit_summary_item'})
    data["credits"] = {}
    for i in credit_summary_item:
        item = i.find("h4")
        names = i.find_all("a")
        data["credits"][item.string] = []
        for i in names:
            data["credits"][item.string].append({
                "link": i["href"],
                "name": i.string
            })
    return data

# %%
details = getMovieDetails("https://www.imdb.com/title/tt2322441/")

# %%
details
# Out:
# {'title': 'Fifty Shades of Grey (2015) - IMDb',
#  'ratingValue': '4.1',
#  'ratingCount': '295,482',
#  'name': 'Fifty Shades of Grey',
#  'subtext': 'R|2h 5min|Drama,Romance,Thriller|13 February 2015 (USA)',
#  'summary_text': "Literature student Anastasia Steele's life changes forever when she meets handsome, yet tormented, billionaire Christian Grey.",
#  'credits': {'Director:': [{'link': '/name/nm0853374/',
#     'name': 'Sam Taylor-Johnson'}],
#   'Writers:': [{'link': '/name/nm0545150/', 'name': 'Kelly Marcel'},
#    {'link': '/name/nm1093317/', 'name': 'E.L. James'}],
#   'Stars:': [{'link': '/name/nm0424848/', 'name': 'Dakota Johnson'},
#    {'link': '/name/nm1946193/', 'name': 'Jamie Dornan'},
#    {'link': '/name/nm0000383/', 'name': 'Jennifer Ehle'},
#    {'link': 'fullcredits/', 'name': 'See full cast & crew'}]}}

# %%
details['credits']['Stars:']
# Out:
# [{'link': '/name/nm0424848/', 'name': 'Dakota Johnson'},
#  {'link': '/name/nm1946193/', 'name': 'Jamie Dornan'},
#  {'link': '/name/nm0000383/', 'name': 'Jennifer Ehle'},
#  {'link': 'fullcredits/', 'name': 'See full cast & crew'}]

# %%
for i in details['credits']['Stars:']:
    if i['name'] != 'See full cast & crew':
        print(i['name'])
# Out:
# Dakota Johnson
# Jamie Dornan
# Jennifer Ehle

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "fault in our stars imdb"
  
for j in search(query, tld="co.in", num=10, stop=1, pause=1): 
    print(j)
# Out:
# https://www.imdb.com/title/tt2582846/

# %%
g = search(query, stop=1)
a = next(g)

# %%
print(a)
# Out:
# https://www.imdb.com/title/tt2582846/
